# %% [markdown]
# #ICS 4C

# %% [markdown]
# **GROUP MEMBERS**
#
# **111218 Shyleen Mwadeghu**
#
# **121200 Okeyo Hope Diane**
#
# **123854 Priscilah Agunda**
#
# **121435 Njeru Boaz Muthomi**
#
# **118461 Sharon Ndichu**
#
# **120352 Steven Mburu Githinji**

# %% [markdown]
# #**LAB ACTIVITY 1**

# %% [markdown]
# ##***1.FLEX***
# ###***Definition***
# FLEX is  a tool or computer program for generating lexical analyzers.It is designed to automatically and quickly generate scanners, also known as tokenizers. The function yylex() is automatically generated by the flex when it is provided with a .l file and this yylex() function is expected by parser to call to retrieve tokens from current/this token stream [Flex](https://www.geeksforgeeks.org/flex-fast-lexical-analyzer-generator/).
#
# ###***Diagram***
# ![flex.png](data:image/png;base64,...)
#
# ###***Code Snippet***
#  Below is a code snippet to count number of characters and number of lines in an input. It shows the use of flex:
#  ![flexcode.png](data:image/png;base64,...)

# %% [markdown]
# ##***2. LEX***
#
# ###***Definition***
# A program generator called LEX was created for the lexical processing of character input and output streams.
# A C compiler, which converts a program into efficient code, or a basic text search software that scans an input-output file for patterns.
#
# ###***Diagram***
# ![Screenshot 2022-09-12 132322.png](data:image/png;base64,...)
#
# ###***Code Snippet***
#
# flex -o scanC.cc scanC.l
#
#  g++ -std=c++11 -o scanC scanC.cc
#
# $ ./scanC < scanC.txt
# Hello Compiler Construction.

# %% [markdown]
# ##***3. Bison***
#
# ###***Definition***
# Bison is a general-purpose parser generator that converts an annotated context-free grammar into a deterministic LR or generalized LR (GLR) parser employing LALR parser tables. As an experimental feature, Bison can also generate IELR or canonical LR parser tables. Once you are proficient with Bison, you can use it to develop a wide range of language parsers, from those used in simple desk calculators to complex programming languages
#
# ###***Diagram***

# %% [markdown]
# ![bisonp.PNG](data:image/png;base64,...)

# %% [markdown]
# ###***Code Snippet***
#
# This example shows a simple double-precision Reverse Polish Notation calculator. In the snippet below shows C and Bison declarations for the calculator
#
# ![Capture1.PNG](data:image/png;base64,...)
#
# Below are the grammar rules for the Reverse Polish Notation Calculator
#
# ![Capture2.PNG](data:image/png;base64,...)

# %% [markdown]
# **4. YACC**

# %% [markdown]
# **Defination**
#
# YACC (yet another compiler-compiler) is an LALR(1) (LookAhead, Left-to-right, Rightmost derivation producer with 1 lookahead token) parser generator, that was originally designed for being complemented by Lex.  It is used to produce the source code of the syntactic analyzer of the language produced by LALR (1) grammar.

# %% [markdown]
# **Diagram**
#
# ![yacc_1.png](data:image/png;base64,...)

# %% [markdown]
# **Code Snippet**
#
# %{
# include <ctype.h>
#
# include <stdio.h>
#
# define YYSTYPE double /* double type for yacc stack */
# %}
#
# %%
#
# Lines : Lines S '\n' {
#
# 	printf("OK \n");
#
#  }
#
# 	| S '\n’
# 	| error '\n' {yyerror("Error: reenter last line:");
# 						yyerrok; };
# S	 : '(' S ')’
#
# 	| '[' S ']’
#
# 	| /* empty */ ;
#
# %%
#
# include "lex.yy.c"
#
# void yyerror(char * s)
#
# /* yacc error handler */
#
# {
#
# fprintf (stderr, "%s\n", s);
#
# }
#
# int main(void)
#
# {
#
# return yyparse();
#
# }

# %% [markdown]
# #**LAB ACTIVITY 2**

# %% [markdown]
# 1. Using any TWO examples, show the conversion of NFA to DFA

# %% [markdown]
# ![nfadfa.png](data:image/png;base64,...)

# %% [markdown]
# ![Compiler.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 2. Using the material on E-Learning, show how to use Flex and Bison when building a
# simple lexical analyzer.

# %% [markdown]
# **LEX FILE PROVIDED ON E-LEARNING**
#
# ![lex specifications.PNG](data:image/png;base64,...)

# %% [markdown]
# **USING FLEX and BISON to BUILD a LEXICAL ANALYZER WITH RESPECT to the MATERIAL PROVIDED in CLASS**

# %% [markdown]
# **DIAGRAM**
#
# Flex and Bison diagrams are illustrated in lab 1 work.

# %% [markdown]
# **FLEX AND BISON**
#
# **Bison Commands**
#
# –defines[=FILE] : It also produce a header file.
#
# -d : It's likewise but cannot specify FILE (for POSIX Yacc).
#
# -r, –report=THINGS : It also produce details on the automaton.
#
# –report-file=FILE : It write report to FILE.
#
# -v, –verbose : It same as '–report=state'.
#
# **Flex**
#
# Flex is a tool for generating scanners. A scanner is a program which recognizes lexical patterns in text. The flex program reads the given input files, or its standard input if no file names are given, for a description of a scanner to generate.
#
# https://www.youtube.com/watch?v=LpVufkH4gog (Flex Video Link)
#
# **BRIEF EXPLANATION**
#
# Vern Paxson created FLEX (rapid lexical analyzer generator) in 1987 as a tool or computer software for creating lexical analyzers (scanners or lexers). It is used in conjunction with the GNU Bison parser generator or the Berkeley Yacc parser generator. Flex and Bison both produce faster code than Lex and Yacc and are more flexible.
# From the user-provided input file, Bison generates a parser. When given a.l file, Flex will automatically build the function yylex(), which the parser will use in order to collect tokens from the current or this token stream.
#
# The main Flex function that executes the Rule Section is called yylex(), and the extension (.l) is used to store applications.
#
#
#
#
# **LEX ANALYZER GENERATOR**
#
# The Lexical Analyzer Generator introduces a tool named Lex that enables users to specify lexical analyzers by using regular expressions to characterize token pattern.
# Lex language is used as the tool's input.
# A lex program will always be converted into a C code file called lex.yy.c by the lex compiler.
#
# ![image.png](data:image/png;base64,...)
#
#  C code is then compiled by C compiler and produce a file called a.out
#
#  ![image.png](data:image/png;base64,...)
#
#  The C compiler output is a working lexical analyzer that can take a stream of input character and produce a stream of tokens
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**LAB ACTIVITY 3**

# %% [markdown]
#  Develop a simple lexer by developing your

# %% [markdown]
# **Code**
#
#
# ```
# /* Declare two counters for the number
# of lines and the other for number of characters */
# %{
# int number_lines = 0;
# int number_chars = 0;
# %}
#
# /***rule 1 counts the number of lines,
# rule 2 counts the number of characters
# and rule 3 specifies when to stop
# taking input***/
# %%
# \n	 ++number_lines;
# .	 ++number_chars;
# end	 return 0;
# %%
#
# /* User code section***/
# int yywrap(){}
# int main(int argc, char **argv)
# {
#
# yylex();
# printf("The number of lines written are = %d, The number of chars written are= %d\n",
# 	number_lines, number_chars );
#
# return 0;
# }
# ```

# %% [markdown]
# **Snipshot of the lab**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # #**LAB ACTIVITY 4 (Understanding Predictive Parsing)**

# %% [markdown]
# **Predictive Parsing**
#
# A predictive parser is a recursive descent parser with no backtracking or backup. It is a top-down parser that does not require backtracking. At each step, the choice of the rule to be expanded is made upon the next terminal symbol.
#
# Predictive parsing is a special kind of recursive descent parsing that does not require backtracking in order to forecast which products to use in place of the input string.

# %% [markdown]
# **Predictive Parsing Diagram**
#
# ![parsing.png](data:image/png;base64,...)

# %% [markdown]
# **Predictive Parsing Algorithm**
#
# 1. Make a transition diagram(DFA/NFA) for every rule of grammar.
# 2. Optimize the DFA by reducing the number of states, yielding the final transition diagram.
# 3. Simulate the string on the transition diagram to parse a string.
# 4. If the transition diagram reaches an accept state after the input is consumed, it is parsed.

# %% [markdown]
# **LL(1) Parsing**
#
# LL(1) parsing is a non-recursive predictive parsing or table-driven parsing that follows the leftmost derivation (LMD).
#
# The main problem during predictive parsing is that of determining the production to be applied for a non-terminal.
# It is solved by a LL(1) parser which looks up which product to be applied in a parsing table.
#
# **LL(1) Parser Components**
#
# 1. Buffer: an input buffer which contains the string to be passed
#
# 2. Stack: a pushdown stack which contains a sequence of grammar symbols
#
# 3. A parsing table: a 2d array M[A, a]
#     where
#     A->non-terminal, a->terminal or $
#
# 4. Output stream:
#  end of the stack and an end of the input symbols are both denoted with $
#
# **First() and Follow()**
#
# First and Follow sets are needed so that the parser can properly apply the needed production rule at the correct position.
#
#
# **First()**
#
# First(α) is a set of terminal symbols that begin in strings derived from α.
#
# **Example**
#
# A → abc / def / ghi
#
# First(A) = { a , d , g }  ;i.e all the terminals that directly terminate from A.
#
# **Rules For Calculating First Function-**
#
#
# **Rule-01:**
#
#
# For a production rule X → ∈,
#
# First(X) = { ∈ }
#
#
#
# **Rule-02:**
#
#
# For any terminal symbol ‘a’,
#
# First(a) = { a }
#
#
#
# **Rule-03:**
#
#
# For a production rule X → Y1Y2Y3,
#
#
#
# **Calculating First(X)**
#
#
# If ∈ ∉ First(Y1), then First(X) = First(Y1)
# If ∈ ∈ First(Y1), then First(X) = { First(Y1) – ∈ } ∪ First(Y2Y3)
#
#
# **Calculating First(Y2Y3)**
#
#
# If ∈ ∉ First(Y2), then First(Y2Y3) = First(Y2)
# If ∈ ∈ First(Y2), then First(Y2Y3) = { First(Y2) – ∈ } ∪ First(Y3)
#
#
# Similarly, we can make expansion for any production rule X → Y1Y2Y3…..Yn.
#
# **Follow()**
#
# Follow(α) is a set of terminal symbols that appear immediately to the right of α.
#
# **Rules For Calculating Follow Function**
#
#
# **Rule-01:**
#
#
# For the start symbol S, place $ in Follow(S).
#
#
#
# **Rule-02:**
#
#
# For any production rule A → αB,
#
# Follow(B) = Follow(A)
#
#
#
# **Rule-03:**
#
#
# For any production rule A → αBβ,
#
#
#
# If ∈ ∉ First(β), then Follow(B) = First(β)
# If ∈ ∈ First(β), then Follow(B) = { First(β) – ∈ } ∪ Follow(A)
#
#
# **Important Notes**
#
#
# **Note-01:**
#
#
# ∈ may appear in the first function of a non-terminal.
# ∈ will never appear in the follow function of a non-terminal.
#
#
# **Note-02:**
#
#
# Before calculating the first and follow functions, eliminate Left Recursion from the grammar, if present.
#
#
# **Note-03:**
#
#
# We calculate the follow function of a non-terminal by looking where it is present on the RHS of a production rule ;i.e
#
# If a NT is at the extreme right of the CFG, its follow is the follow of the left hand side(Starting Symbol).
#
# For a NT A, such that X->AB, its follow is the first of B.
#
# **Note-04**
#
# Once you have identified a symbol either as a first() or a follow() you do not need to repeat it in case it appears again.

# %% [markdown]
#  **Unique attributes associated with Top-Down parsing**
#
# Top-down parsing technique parses the input, and starts constructing a parse tree from the root node gradually moving down to the leaf nodes.
#
# **Top-Down Parsing Approaches**
#
# **Recursive descent parsing** : It is a common form of top-down parsing. It is called recursive as it uses recursive procedures to process the input. Recursive descent parsing suffers from backtracking.
#
# **Backtracking** : It means, if one derivation of a production fails, the syntax analyzer restarts the process using different rules of same production. This technique may process the input string more than once to determine the right production.
#
# **Unique Features**
#
# 1. First looks at the highest level of the parse tree and works down the parse tree by using the rules of grammar. i.e Starts from the root to the leaf nodes (NT to Terminals).
#
# 2. Uses Left Most Derivation.
#
# **Major Problem of Top-Down Parsing**
#
# The key problem in top-down parsing is to identify which production of a non-terminal must be chosen. Such that the terminals in the production body match the terminals in the input string.
#
# **Diagram/Types of Top-Down Parsing**
#
#
# ![Types-of-Top-Down-Parsing-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# ### **LAB ACTIVITY 5**
#
# **1. Review what syntax analysis is and in a few words, describe what this phase of compiler construction entails**
#
# Syntax analysis or parsing is the second phase of a compiler. A lexical analyzer can identify tokens with the help of regular expressions and pattern rules. But a lexical analyzer cannot check the syntax of a given sentence due to the limitations of the regular expressions. Regular expressions cannot check balancing tokens, such as parenthesis. Therefore, this phase uses context-free grammar (CFG), which is recognized by push-down automata.
#
# CFG, on the other hand, is a superset of Regular Grammar which implies that every Regular Grammar is also context-free, but there exist some problems, which are beyond the scope of Regular Grammar.
# A syntax analyzer or parser takes the input from a lexical analyzer in the form of token streams. The parser analyzes the source code (token stream) against the production rules to detect any errors in the code. The output of this phase is a parse tree. In this way, the parser accomplishes tasks, i.e., parsing the code, looking for errors and generating a parse tree as the output of the phase. Parsers are expected to parse the whole code even if some errors exist in the program. Parsers overcome this using error recovery strategies. The following is an image of a parse tree:
#
#
# ![Screenshot (12).png](data:image/png;base64,...)

# %% [markdown]
# **2. Using Flex (lexical analyzer) and Bison (yacc), show how one can develop a simple  syntax analyzer. [Consult the web, show and explain the simple codes that you find].**
#
# Flex and Bison are both tools used to parse input strings. Initially, they served as tools for creating compilers. But they are also helpful in a lot of other situations. Flex has the ability to convert strings into tokens. and Bison will verify these tokens if the syntax is correct.
#
# This code from the Medium Website will help explain how flex and bison can be used to create simple syntax analyzers.
#  ![flex parser code.png](data:image/png;base64,...)
#
# ![bison parser code.png](data:image/png;base64,...)![bison.png](data:image/png;base64,...)
#
# The first image shows how Flex copies the code to a .c file after the declarations of the variables.
# Next, C code is present in the scope. That refers to what Flex will do following a match between the input string and the regular expression that you specify. The string is represented by a *char data type called yytext .When Flex scans input 'a,' it will convert it to the token LOWERCASE and notify Bison.
# Therefore, these codes function to determine what the input is if it is 'a'. Let Bison know that it is a LOWERCASE token. The value of this token is "a."
#
# Secondly, Bison will parse the tokens that come from flex.
# After declarations the second part is the grammar rules. The "size" token may be a INTEGER token. It will run the code in when the input conforms to the grammar. The code in is written in C. Size=INTEGER is indicated by $$=$1. For instance, if the input is 3, the INTEGER token will be 3, and you can obtain this value from the $1 variable and assign the number to the'size' token by using $$=$1.
#
# First flex is run then bison, aftet that stage they are compiled together using the flex library.
#
# *Other code examples*
# **This is a syntax analyzer that can identify a valid statement and print success when it does.**
#
# %{
#
# #include <stdio.h>
# //include the c function 'exit'
# #include <stdlib.h>
# %}
#
# %start Stmt_list
# %token Id Num Relop Addop Mulop Assignop Not
#
# %%
# Stmt_list   : Stmt ';' '\n' {printf ("\n Success. \n"); exit(0);}
#         | Stmt_list Stmt ';' '\n'   {printf ("\n Success. \n"); exit(0);}
#         | error '\n'    {printf ("\n Invalid. \n"); exit(1);}
#         ;
#
# Stmt    : Variable Assignop Expression
#     ;
#
# Variable    : Id
#         | Id '['Expression']'
#         ;
#
# Expression  : Simple_expression
#         | Simple_expression Relop Simple_expression
#         ;
#
# Simple_expression   : Term
#             | Simple_expression Addop Term
#             ;
#
# Term    : Factor
#     | Term Mulop Factor
#     ;
#
# Factor  : Id
#     | Num
#     | '(' Expression ')'
#     | Id '[' Expression ']'
#     | Not Factor
#     ;
#
# %%
#
# #include"lex.yy.c"
#
# int main()
# {
#     yyparse();
#     yylex();
#
# }
#
# yyerror(char *s)
# {
#  printf("\nError\n");
# }

# %% [markdown]
# # LAB ACTIVITY 6

# %% [markdown]
# **SUMMARY OF THE FRONT END**
#
# The front end of a compiler is the analysis phase that reads the source program, divides it into core parts and then checks for lexical, grammar and syntax errors.
#
# It is made of the lexical analyzer, semantic analyzer, syntax analyzer and an intermediate code generator.
#
# **DIAGRAMATIC REPRESENTATION OF THE FRONT END**
#
# ![Front-end.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **LEXICAL ANALYSIS**
#
# Lexical analysis involves taking a program written in some programming language as a stream of characters and breaking it into a stream of tokens.
#
# The characters are taken from the source program and organized into lexemes (groups of characters that are similar) and each lexeme has a corresponding token.
#
# Regular expressions that the lexical analyzer can understand are used to define tokens. The lexical analyzer eliminates white space, comments and lexical mistakes.
#
# ![the-architecture-of-lexical-analyzer.png](data:image/png;base64,...)
#
# Assuming the source code used is in the form, x+y/3=z ; the lexical analyzer will break the equation into tokens as represented below.
#
# x+y/3=z
#
# <id,x>
#
# <op,+>
#
# <id,y>
#
# <op,/>
#
# <int,3>
#
# <op,= >
#
# <id, z>

# %% [markdown]
# **SYNTAX ANALYSIS (PARSER)**
#
# The parser receives token streams as input from a lexical analyzer. To find any coding flaws, the parser examines the source code (token stream) in comparison to the production rules and the output is a parse tree.
#
# To detect the validity of a string of characters, the syntax analyzer uses a Context Free Grammar (CFG) or a parse tree, where one may either use the Left Most Derivation (LMD) or the Right Most Derivation (RMD).
#
# **CONTEXT FREE GRAMMAR(CFG)**
#
# This is a formal language with productions or rules governing a certain grammar. It is made up of four tuples:
#
# Starting symbol(S)
#
# *  Starting symbol(S)
# *  Non-terminals(N)
# *  Terminals(T)
# *  Productions/rules
#
# For example, a string x*3-y to be solved using LMD can be represented as;
#
# **CFG**
#
# expr ? expr  op  expr
#
# expr ? num/id
#
# op   ? */-/+/-
#
# **SOLUTION USING LMD**
#
# expr ? expr op expr
#
#      ? id<x> op expr
#
#      ? id<x> * expr
#
#      ? id<x> * expr op expr
#
#      ? id<x> * num<3> op expr
#
#      ? id<x> * num <3> - expr
#
#      ? id<x> * num<3< - id <y>

# %% [markdown]
# **PARSE TREE**
#
# A parse tree is an ordered, rooted tree that represents the syntactic structure of a string.
#
# It has two main approaches;
# 1.  Top-down Parsing
#
# Top-Down Parsing is based on Left Most Derivation.
#
# ![topdown.jpeg](data:image/jpeg;base64,...)
#
# Example
#
# ![Top down parsing.jpg](data:image/jpeg;base64,...)
#
# 2.  Bottom Up Parsing
#
# Bottom-up parsing starts from the leaf nodes of a tree and works in upward direction till it reaches the root node.
#
# It uses the Right Most Derivation.
#
# ![image.png](data:image/png;base64,...)
#
#
# Example
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SEMANTIC ANALYZER**
#
# It verifies the parse tree, whether it’s meaningful or not. It furthermore produces a verified parse tree. It also does type checking, Label checking, and Flow control checking.
#
# It gathers type information and stores it in either syntax tree or symbol table that is subsequently used by compiler during intermediate-code generation.
#
# **Semantic Errors:**
#
# Errors recognized by semantic analyzer are as follows:
#
# 1.Type mismatch
#
# 2.Undeclared variables
#
# 3.Reserved identifier misuse
#
# **Functions of Semantic Analysis:**
#
# Type Checking –
# Ensures that data types are used in a way consistent with their definition.
#
# Label Checking –
# A program should contain labels references.
#
# Flow Control Check –
# Keeps a check that control structures are used in a proper manner.(example: no break statement outside a loop)
#
# **Example:**
#
# float x = 10.1;
#
# float y = x*30;
#
# In the above example integer 30 will be typecasted to float 30.0 before multiplication, by semantic analyzer.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **INTERMEDIATE CODE GENERATOR**
#
# It produces intermediate code, which is a format that a machine can easily execute. The final two processes, which depend on the platform, translate intermediate code into machine language.
#
# Every compiler in existence produces intermediate code in the same way, but after that, the platform determines how things work. We don't have to create a new compiler from scratch. The last two components can be created using the intermediate code from the already-existing compiler.
#
# **Code optimization**: This process changes the code to use less resources and run more quickly. The changed code retains its original meaning. The two types of optimization are machine-dependent and machine-independent.
#
# **The Target Code Generator**: creates code that the machine can understand while simultaneously performing register allocation, instruction selection, etc. The type of assembler determines the output. This is the last step in the compilation process. The optimized code is transformed into relocatable machine code and used as the linker and loader's input.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # LAB ACTIVITY 7

# %% [markdown]
# 1. Write the three address code (TAC) of the following:
#
# a. Any if-statment of your choice
# if a<b then x=y+z else p=q+r
#
# **SOLUTION**
# 1. If a<b goto(3)
# 2. goto (6)
# 3. T1= y+z
# 4. x= T1
# 5. goto
# 6. T2=q+r
# 7. p= T2
#
# b. Any for-loop of your choice
#
#   for(i=1; i<=20, i++)
#
#    x = y+z
#
# **SOLUTION**
#
#   1. i=1
#   2. if i<=20 goto (7)
#   3. goto
#   4. T1 = i+1
#   5. i= T1
#   6. goto(2)
#   7. T2 = y + z
#   8. x= T2
#   9. goto(4)
#
# C. Any while loop of your choice
#
#
# while (A < C and B > D) do
# if A = 1 then C = C + 1
# else
# while A <= D
# do A = A + B
#
# **SOLUTION**
# 1. if (A < C) goto (3)
# 2. goto (15)
# 3. if (B > D) goto (5)
# 4. goto (15)
# 5. if (A = 1) goto (7)
# 6. goto (10)
# 7. T1 = c + 1
# 8. c = T1
# 9. goto (1)
# 10. if (A <= D) goto (12)
# 11. goto (1)
# 12. T2 = A + B
# 13. A = T2
# 14. goto (10)
# 15.

# %% [markdown]
# Below is the implementation of the for loop:

# %% [markdown]
# 2. Write the triple implmenetation of one of the TAC's in question 1 above.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**REFERENCES**
# 1. https://www.geeksforgeeks.org/flex-fast-lexical-analyzer-generator/(flex)
#
# 2. https://www.geeksforgeeks.org/introduction-to-yacc/ (Yacc)
# 3. https://www.gnu.org/software/bison/ (bison)
# 4. http://estudies4you.blogspot.com/2017/07/designing-of-lexical-analyzer.html(lab 2)
#
# 5. https://www.gatevidyalay.com/first-and-follow-compiler-design/#:~:text=First%20and%20Follow%20sets%20are,calculate%20first%20and%20follow%20functions.
#
# 6. https://www.geeksforgeeks.org/algorithm-for-non-recursive-predictive-parsing/
#
# 7. K. (2022, January 10). Using Flex and Bison to parse the regular expression | by Ken | Medium. Medium. Retrieved October 26, 2022, from https://ken8989580.medium.com/using-flex-and-bison-to-parse-the-regular-expression-3eb3004539b8
# 8. https://www.tutorialspoint.com/compiler_design/compiler_design_syntax_analysis.htm
# 9. https://www.geeksforgeeks.org/semantic-analysis-in-compiler-design/#:~:text=Semantic%20Analyzer%3A,compiler%20during%20intermediate%2Dcode%20generation.
